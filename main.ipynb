# %%
import pandas as pd
import numpy as np
df = pd.read_csv('database.csv')

# %%
df.head()
# Out:
#          Date      Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0  01/02/1965  13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 1  01/04/1965  11:29:49     1.863    127.352  Earthquake   80.0          NaN
# 2  01/05/1965  18:05:58   -20.579   -173.972  Earthquake   20.0          NaN
# 3  01/08/1965  18:49:43   -59.076    -23.557  Earthquake   15.0          NaN
# 4  01/09/1965  13:32:50    11.938    126.427  Earthquake   15.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 0                     NaN        6.0             MW  ...
# 1                     NaN        5.8             MW  ...
# 2                     NaN        6.2             MW  ...
# 3                     NaN        5.8             MW  ...
# 4                     NaN        5.8             MW  ...
#
#    Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                         NaN            NaN                  NaN
# 1                         NaN            NaN                  NaN
# 2                         NaN            NaN                  NaN
# 3                         NaN            NaN                  NaN
# 4                         NaN            NaN                  NaN
#
#    Horizontal Error  Root Mean Square            ID  Source Location Source  \
# 0               NaN               NaN  ISCGEM860706  ISCGEM          ISCGEM
# 1               NaN               NaN  ISCGEM860737  ISCGEM          ISCGEM
# 2               NaN               NaN  ISCGEM860762  ISCGEM          ISCGEM
# 3               NaN               NaN  ISCGEM860856  ISCGEM          ISCGEM
# 4               NaN               NaN  ISCGEM860890  ISCGEM          ISCGEM
#
#   Magnitude Source     Status
# 0           ISCGEM  Automatic
# 1           ISCGEM  Automatic
# 2           ISCGEM  Automatic
# 3           ISCGEM  Automatic
# 4           ISCGEM  Automatic
#
# [5 rows x 21 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%m/%d/%Y', errors='coerce')

df['Time'] = pd.to_datetime(df['Time'], format='%H:%M:%S', errors='coerce')

# combine
df['DateTime'] = df['Date'] + pd.to_timedelta(df['Time'].dt.strftime('%H:%M:%S'))

df.drop(['Date', 'Time'], axis=1, inplace=True)

# check for any NaT values in the 'DateTime' column
print("Number of NaT values in DateTime column:", df['DateTime'].isnull().sum())

df.head()
# Out:
# Number of NaT values in DateTime column: 3
#    Latitude  Longitude        Type  Depth  Depth Error  \
# 0    19.246    145.616  Earthquake  131.6          NaN
# 1     1.863    127.352  Earthquake   80.0          NaN
# 2   -20.579   -173.972  Earthquake   20.0          NaN
# 3   -59.076    -23.557  Earthquake   15.0          NaN
# 4    11.938    126.427  Earthquake   15.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type  Magnitude Error  \
# 0                     NaN        6.0             MW              NaN
# 1                     NaN        5.8             MW              NaN
# 2                     NaN        6.2             MW              NaN
# 3                     NaN        5.8             MW              NaN
# 4                     NaN        5.8             MW              NaN
#
#    Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                         NaN            NaN                  NaN
# 1                         NaN            NaN                  NaN
# 2                         NaN            NaN                  NaN
# 3                         NaN            NaN                  NaN
# 4                         NaN            NaN                  NaN
#
#    Horizontal Error  Root Mean Square            ID  Source Location Source  \
# 0               NaN               NaN  ISCGEM860706  ISCGEM          ISCGEM
# 1               NaN               NaN  ISCGEM860737  ISCGEM          ISCGEM
# 2               NaN               NaN  ISCGEM860762  ISCGEM          ISCGEM
# 3               NaN               NaN  ISCGEM860856  ISCGEM          ISCGEM
# 4               NaN               NaN  ISCGEM860890  ISCGEM          ISCGEM
#
#   Magnitude Source     Status            DateTime
# 0           ISCGEM  Automatic 1965-01-02 13:44:18
# 1           ISCGEM  Automatic 1965-01-04 11:29:49
# 2           ISCGEM  Automatic 1965-01-05 18:05:58
# 3           ISCGEM  Automatic 1965-01-08 18:49:43
# 4           ISCGEM  Automatic 1965-01-09 13:32:50

# %%
df.describe()
# Out:
#            Latitude     Longitude         Depth  Depth Error  \
# count  23412.000000  23412.000000  23412.000000  4461.000000
# mean       1.679033     39.639961     70.767911     4.993115
# min      -77.080000   -179.997000     -1.100000     0.000000
# 25%      -18.653000    -76.349750     14.522500     1.800000
# 50%       -3.568500    103.982000     33.000000     3.500000
# 75%       26.190750    145.026250     54.000000     6.300000
# max       86.005000    179.998000    700.000000    91.295000
# std       30.113183    125.511959    122.651898     4.875184
#
#        Depth Seismic Stations     Magnitude  Magnitude Error  \
# count             7097.000000  23412.000000       327.000000
# mean               275.364098      5.882531         0.071820
# min                  0.000000      5.500000         0.000000
# 25%                146.000000      5.600000         0.046000
# 50%                255.000000      5.700000         0.059000
# 75%                384.000000      6.000000         0.075500
# max                934.000000      9.100000         0.410000
# std                162.141631      0.423066         0.051466
#
#        Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# count                 2564.000000    7299.000000          1604.000000
# mean                    48.944618      44.163532             3.992660
# min                      0.000000       0.000000             0.004505
# 25%                     10.000000      24.100000             0.968750
# 50%                     28.000000      36.000000             2.319500
# 75%                     66.000000      54.000000             4.724500
# max                    821.000000     360.000000            37.874000
# std                     62.943106      32.141486             5.377262
#
#        Horizontal Error  Root Mean Square                       DateTime
# count       1156.000000      17352.000000                          23409
# mean           7.662759          1.022784  1993-02-18 12:19:39.880815104
# min            0.085000          0.000000            1965-01-02 13:44:18
# 25%            5.300000          0.900000            1981-04-11 05:29:33
# 50%            6.700000          1.000000            1993-11-30 20:44:13
# 75%            8.100000          1.130000            2005-09-09 19:55:22
# max           99.000000          3.440000            2016-12-30 20:08:28
# std           10.430396          0.188545                            NaN

# %%
df['Depth'] = pd.to_numeric(df['Depth'], errors='coerce')

# Define the bins and labels for categorizing the depth values based on the actual data range
depth_bins = [0, 10, 20, 30, 40, float('inf')]
depth_labels = ['Very Shallow', 'Shallow', 'Intermediate', 'Deep', 'Very Deep']

# Categorize the 'Depth' values using the cut() function
df['DepthCategory'] = pd.cut(df['Depth'], bins=depth_bins, labels=depth_labels)

# %%
# Check the distribution of DepthCategory
print("Distribution of DepthCategory:")
df['DepthCategory'].value_counts()
# Out:
# Distribution of DepthCategory:
# DepthCategory
# Very Deep       7604
# Deep            5928
# Very Shallow    4753
# Shallow         2559
# Intermediate    2395
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Latitude', 'Longitude', 'Type', 'Depth', 'Depth Error',
#        'Depth Seismic Stations', 'Magnitude', 'Magnitude Type',
#        'Magnitude Error', 'Magnitude Seismic Stations', 'Azimuthal Gap',
#        'Horizontal Distance', 'Horizontal Error', 'Root Mean Square', 'ID',
#        'Source', 'Location Source', 'Magnitude Source', 'Status', 'DateTime',
#        'Magnitude Category', 'DepthCategory'],
#       dtype='object')

# %%
melted_df = pd.melt(df, id_vars=['ID', 'DateTime'], value_vars=['Latitude', 'Longitude', 'Type', 'Depth', 'Magnitude', 'Magnitude Type'])

# %%
melted_df
# Out:
#                   ID            DateTime        variable   value
# 0       ISCGEM860706 1965-01-02 13:44:18        Latitude  19.246
# 1       ISCGEM860737 1965-01-04 11:29:49        Latitude   1.863
# 2       ISCGEM860762 1965-01-05 18:05:58        Latitude -20.579
# 3       ISCGEM860856 1965-01-08 18:49:43        Latitude -59.076
# 4       ISCGEM860890 1965-01-09 13:32:50        Latitude  11.938
# ...              ...                 ...             ...     ...
# 140467    NN00570710 2016-12-28 08:22:12  Magnitude Type      ML
# 140468    NN00570744 2016-12-28 09:13:47  Magnitude Type      ML
# 140469    US10007NAF 2016-12-28 12:38:51  Magnitude Type     MWW
# 140470    US10007NL0 2016-12-29 22:30:19  Magnitude Type     MWW
# 140471    US10007NTD 2016-12-30 20:08:28  Magnitude Type      MB
#
# [140472 rows x 4 columns]

# %%
pivot_df = pd.pivot_table(df, index='Type', columns='Magnitude Type', values='Magnitude', aggfunc='mean')

# %%
pivot_df
# Out:
# Magnitude Type           MB        MD    MH        ML       MS        MW  \
# Type
# Earthquake         5.674541  5.966667  6.54  5.842462  5.99436  5.933794
# Explosion          5.850000       NaN   NaN       NaN      NaN       NaN
# Nuclear Explosion  5.864417       NaN   NaN  5.664167      NaN       NaN
# Rock Burst              NaN       NaN   NaN       NaN      NaN       NaN
#
# Magnitude Type          MWB       MWC       MWR       MWW
# Type
# Earthquake         5.907282  5.858116  5.630769  6.008674
# Explosion               NaN       NaN       NaN       NaN
# Nuclear Explosion       NaN       NaN       NaN       NaN
# Rock Burst              NaN  6.200000       NaN       NaN

# %%
# linear
plt.figure(figsize=(12, 6))
plt.plot(df['DateTime'], df['Magnitude'], linewidth=2, marker='o')
plt.xlabel('თარიღი და დრო')
plt.ylabel('მაგნიტუდა')
plt.title('მიწისძვრის მაგნიტუდა დროში')
plt.grid(True)
plt.xticks(rotation=45)
plt.show()

# %%
# Bar Chart: Count of earthquake types
plt.figure(figsize=(10, 6))
df['Type'].value_counts().plot(kind='bar', color='green')
plt.title('Count of Earthquake Types')
plt.xlabel('Type')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %%
# Scatter
plt.figure(figsize=(10, 6))
plt.scatter(df['Magnitude'], df['Depth'], color='red', alpha=0.5)
plt.title('Magnitude vs Depth')
plt.xlabel('Magnitude')
plt.ylabel('Depth')
plt.grid(True)
plt.show()

# %%
# Histogram
plt.figure(figsize=(10, 6))
plt.hist(df['Depth'], bins=20, color='orange', edgecolor='black')
plt.title('Distribution of Earthquake Depths')
plt.xlabel('Depth')
plt.ylabel('Frequency')
plt.grid(axis='y')
plt.show()

# %%
df.head()
# Out:
#                                                                                                    Latitude  \
# Date       Time     Latitude Longitude Type       Depth Depth Error Depth Seismic Stations  Magnitude Error
# 01/02/1965 13:44:18 19.246   145.616   Earthquake 131.6 NaN         NaN                                 NaN
# 01/04/1965 11:29:49 1.863    127.352   Earthquake 80    NaN         NaN                                 NaN
# 01/05/1965 18:05:58 -20.579  -173.972  Earthquake 20    NaN         NaN                                 NaN
# 01/08/1965 18:49:43 -59.076  -23.557   Earthquake 15    NaN         NaN                                 NaN
#
#                                                                                                              Longitude  \
# Date       Time     Latitude Longitude Type       Depth Depth Error Depth Seismic Stations  Magnitude Seismic Stations
# 01/02/1965 13:44:18 19.246   145.616   Earthquake 131.6 NaN         NaN                                            NaN
# 01/04/1965 11:29:49 1.863    127.352   Earthquake 80    NaN         NaN                                            NaN
# 01/05/1965 18:05:58 -20.579  -173.972  Earthquake 20    NaN         NaN                                            NaN
# 01/08/1965 18:49:43 -59.076  -23.557   Earthquake 15    NaN         NaN                                            NaN
#
#                                                                                                     Event  \
# Date       Time     Latitude Longitude Type       Depth Depth Error Depth Seismic Stations  Azimuthal Gap
# 01/02/1965 13:44:18 19.246   145.616   Earthquake 131.6 NaN         NaN                               NaN
# 01/04/1965 11:29:49 1.863    127.352   Earthquake 80    NaN         NaN                               NaN
# 01/05/1965 18:05:58 -20.579  -173.972  Earthquake 20    NaN         NaN                               NaN
# 01/08/1965 18:49:43 -59.076  -23.557   Earthquake 15    NaN         NaN                               NaN
#
#                                                                                             Depth  \
# Date       Time     Latitude Longitude Type       Depth Depth Error Depth Seismic Stations    NaN
# 01/02/1965 13:44:18 19.246   145.616   Earthquake 131.6 NaN         NaN                       NaN
# 01/04/1965 11:29:49 1.863    127.352   Earthquake 80    NaN         NaN                       NaN
# 01/05/1965 18:05:58 -20.579  -173.972  Earthquake 20    NaN         NaN                       NaN
# 01/08/1965 18:49:43 -59.076  -23.557   Earthquake 15    NaN         NaN                       NaN
#
#                                                                                             Magnitude  \
# Date       Time     Latitude Longitude Type       Depth Depth Error Depth Seismic Stations        NaN
# 01/02/1965 13:44:18 19.246   145.616   Earthquake 131.6 NaN         NaN                           NaN
# 01/04/1965 11:29:49 1.863    127.352   Earthquake 80    NaN         NaN                           NaN
# 01/05/1965 18:05:58 -20.579  -173.972  Earthquake 20    NaN         NaN                           NaN
# 01/08/1965 18:49:43 -59.076  -23.557   Earthquake 15    NaN         NaN                           NaN
#
#                                                                                                MagnitudeType  \
# Date       Time     Latitude Longitude Type       Depth Depth Error Depth Seismic Stations  Root Mean Square
# 01/02/1965 13:44:18 19.246   145.616   Earthquake 131.6 NaN         NaN                                  NaN
# 01/04/1965 11:29:49 1.863    127.352   Earthquake 80    NaN         NaN                                  NaN
# 01/05/1965 18:05:58 -20.579  -173.972  Earthquake 20    NaN         NaN                                  NaN
# 01/08/1965 18:49:43 -59.076  -23.557   Earthquake 15    NaN         NaN                                  NaN
#
#                                                                                                  EventID  \
# Date       Time     Latitude Longitude Type       Depth Depth Error Depth Seismic Stations            ID
# 01/02/1965 13:44:18 19.246   145.616   Earthquake 131.6 NaN         NaN                     ISCGEM860706
# 01/04/1965 11:29:49 1.863    127.352   Earthquake 80    NaN         NaN                     ISCGEM860737
# 01/05/1965 18:05:58 -20.579  -173.972  Earthquake 20    NaN         NaN                     ISCGEM860762
# 01/08/1965 18:49:43 -59.076  -23.557   Earthquake 15    NaN         NaN                     ISCGEM860856
#
#                                                                                            Source1  \
# Date       Time     Latitude Longitude Type       Depth Depth Error Depth Seismic Stations  Source
# 01/02/1965 13:44:18 19.246   145.616   Earthquake 131.6 NaN         NaN                     ISCGEM
# 01/04/1965 11:29:49 1.863    127.352   Earthquake 80    NaN         NaN                     ISCGEM
# 01/05/1965 18:05:58 -20.579  -173.972  Earthquake 20    NaN         NaN                     ISCGEM
# 01/08/1965 18:49:43 -59.076  -23.557   Earthquake 15    NaN         NaN                     ISCGEM
#
#                                                                                                     Source2  \
# Date       Time     Latitude Longitude Type       Depth Depth Error Depth Seismic Stations  Location Source
# 01/02/1965 13:44:18 19.246   145.616   Earthquake 131.6 NaN         NaN                              ISCGEM
# 01/04/1965 11:29:49 1.863    127.352   Earthquake 80    NaN         NaN                              ISCGEM
# 01/05/1965 18:05:58 -20.579  -173.972  Earthquake 20    NaN         NaN                              ISCGEM
# 01/08/1965 18:49:43 -59.076  -23.557   Earthquake 15    NaN         NaN                              ISCGEM
#
#                                                                                                      Source3  \
# Date       Time     Latitude Longitude Type       Depth Depth Error Depth Seismic Stations  Magnitude Source
# 01/02/1965 13:44:18 19.246   145.616   Earthquake 131.6 NaN         NaN                               ISCGEM
# 01/04/1965 11:29:49 1.863    127.352   Earthquake 80    NaN         NaN                               ISCGEM
# 01/05/1965 18:05:58 -20.579  -173.972  Earthquake 20    NaN         NaN                               ISCGEM
# 01/08/1965 18:49:43 -59.076  -23.557   Earthquake 15    NaN         NaN                               ISCGEM
#
#                                                                                                Status  \
# Date       Time     Latitude Longitude Type       Depth Depth Error Depth Seismic Stations     Status
# 01/02/1965 13:44:18 19.246   145.616   Earthquake 131.6 NaN         NaN                     Automatic
# 01/04/1965 11:29:49 1.863    127.352   Earthquake 80    NaN         NaN                     Automatic
# 01/05/1965 18:05:58 -20.579  -173.972  Earthquake 20    NaN         NaN                     Automatic
# 01/08/1965 18:49:43 -59.076  -23.557   Earthquake 15    NaN         NaN                     Automatic
#
#                                                                                            DateTime  \
# Date       Time     Latitude Longitude Type       Depth Depth Error Depth Seismic Stations      NaT
# 01/02/1965 13:44:18 19.246   145.616   Earthquake 131.6 NaN         NaN                         NaT
# 01/04/1965 11:29:49 1.863    127.352   Earthquake 80    NaN         NaN                         NaT
# 01/05/1965 18:05:58 -20.579  -173.972  Earthquake 20    NaN         NaN                         NaT
# 01/08/1965 18:49:43 -59.076  -23.557   Earthquake 15    NaN         NaN                         NaT
#
#                                                                                            DepthCategory
# Date       Time     Latitude Longitude Type       Depth Depth Error Depth Seismic Stations           NaN
# 01/02/1965 13:44:18 19.246   145.616   Earthquake 131.6 NaN         NaN                              NaN
# 01/04/1965 11:29:49 1.863    127.352   Earthquake 80    NaN         NaN                              NaN
# 01/05/1965 18:05:58 -20.579  -173.972  Earthquake 20    NaN         NaN                              NaN
# 01/08/1965 18:49:43 -59.076  -23.557   Earthquake 15    NaN         NaN                              NaN

# %%
df.dropna(subset=['DateTime'], inplace=True)

df['Year'] = df['DateTime'].dt.year
df['Month'] = df['DateTime'].dt.month
df['Day'] = df['DateTime'].dt.day

monthly_resampled = df.set_index('DateTime').resample('M')['Magnitude'].mean()

# Display the resampled data
monthly_resampled.head()
# Out:
# DateTime
# 1965-01-31    6.123077
# 1965-02-28    5.955556
# 1965-03-31    6.057895
# 1965-04-30    5.945455
# 1965-05-31    5.954545
# Freq: M, Name: Magnitude, dtype: float64
